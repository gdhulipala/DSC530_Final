# %%
import pandas as pd

# %%
weather = pd.read_csv("austin_weather.csv")

# %%
weather.head()
# Out:
#        Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  12/21/13         74        60        45            67           49
# 1  12/22/13         56        48        39            43           36
# 2  12/23/13         58        45        32            31           27
# 3  12/24/13         61        46        31            36           28
# 4  12/25/13         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0           43                  93                 75                 57
# 1           28                  93                 68                 43
# 2           23                  76                 52                 27
# 3           21                  89                 56                 22
# 4           36                  86                 71                 56
#
#           ...          SeaLevelPressureAvgInches SeaLevelPressureLowInches  \
# ...

# %%
weather.dtypes
# Out:
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# WindAvgMPH                    object
# WindGustMPH                   object
# PrecipitationSumInches        object
# Events                        object
# dtype: object

# %%
weather.shape
# Out:
# (1319, 21)

# %%
weather.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
weather["Date"] = pd.to_datetime(weather.Date)

# %%
weather["Year"] = weather.Date.dt.year

# %%
weather.head()
# Out:
#         Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0 2013-12-21         74        60        45            67           49
# 1 2013-12-22         56        48        39            43           36
# 2 2013-12-23         58        45        32            31           27
# 3 2013-12-24         61        46        31            36           28
# 4 2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0           43                  93                 75                 57
# 1           28                  93                 68                 43
# 2           23                  76                 52                 27
# 3           21                  89                 56                 22
# 4           36                  86                 71                 56
#
#    ...  SeaLevelPressureLowInches VisibilityHighMiles VisibilityAvgMiles  \
# ...

# %%
weather.Year.value_counts()
# Out:
# 2016    366
# 2015    365
# 2014    365
# 2017    212
# 2013     11
# Name: Year, dtype: int64

# %%
import numpy as np
#weather['PrecipitationSumInches'] = pd.to_numeric(weather['PrecipitationSumInches'], errors='coerce')
weather.loc[weather["PrecipitationSumInches"] == "T", "PrecipitationSumInches"]= np.nan
weather.PrecipitationSumInches.fillna(value = "NaN", inplace = True)
weather.PrecipitationSumInches = weather["PrecipitationSumInches"].astype(float)

# %%
weather.loc[weather["WindGustMPH"]=="-", "WindGustMPH"] = np.nan
weather.WindGustMPH.fillna(value = "NaN", inplace = True)
weather.WindGustMPH = weather["WindGustMPH"].astype(float)

# %%
weather.loc[weather["WindAvgMPH"]=="-", "WindAvgMPH"] = np.nan
weather.WindAvgMPH.fillna(value = "NaN", inplace = True)
weather.WindAvgMPH = weather["WindAvgMPH"].astype(float)

# %%
weather.loc[weather["WindHighMPH"]=="-", "WindHighMPH"] = np.nan
weather.WindHighMPH.fillna(value = "NaN", inplace = True)
weather.WindHighMPH = weather["WindHighMPH"].astype(float)

# %%
weather.loc[weather["VisibilityLowMiles"]=="-","VisibilityLowMiles"] = np.nan
weather.VisibilityLowMiles.fillna(value = "NaN", inplace = True)
weather.VisibilityLowMiles = weather["VisibilityLowMiles"].astype(float)

# %%
weather.loc[weather["VisibilityAvgMiles"]=="-","VisibilityAvgMiles"] = np.nan
weather.VisibilityAvgMiles.fillna(value = "NaN", inplace = True)
weather.VisibilityAvgMiles = weather["VisibilityAvgMiles"].astype(float)

# %%
weather.loc[weather["VisibilityHighMiles"]=="-","VisibilityHighMiles"] = np.nan
weather.VisibilityHighMiles.fillna(value = "NaN", inplace = True)
weather.VisibilityHighMiles = weather["VisibilityHighMiles"].astype(float)

# %%
weather.loc[weather["SeaLevelPressureLowInches"]=="-","SeaLevelPressureLowInches"] = np.nan
weather.SeaLevelPressureLowInches.fillna(value = "NaN", inplace = True)
weather.SeaLevelPressureLowInches = weather["SeaLevelPressureLowInches"].astype(float)

# %%
weather.loc[weather["SeaLevelPressureAvgInches"]=="-","SeaLevelPressureAvgInches"] = np.nan
weather.SeaLevelPressureAvgInches.fillna(value = "NaN", inplace = True)
weather.SeaLevelPressureAvgInches = weather["SeaLevelPressureAvgInches"].astype(float)

# %%
weather.loc[weather["SeaLevelPressureHighInches"]=="-","SeaLevelPressureHighInches"] = np.nan
weather.SeaLevelPressureHighInches.fillna(value = "NaN", inplace = True)
weather.SeaLevelPressureHighInches = weather["SeaLevelPressureHighInches"].astype(float)

# %%
weather.loc[weather["HumidityLowPercent"]=="-","HumidityLowPercent"] = np.nan
weather.HumidityLowPercent.fillna(value = "NaN", inplace = True)
weather.HumidityLowPercent = weather["HumidityLowPercent"].astype(float)

# %%
weather.loc[weather["HumidityAvgPercent"]=="-","HumidityAvgPercent"] = np.nan
weather.HumidityAvgPercent.fillna(value = "NaN", inplace = True)
weather.HumidityAvgPercent = weather["HumidityAvgPercent"].astype(float)

# %%
weather.loc[weather["HumidityHighPercent"]=="-","HumidityHighPercent"] = np.nan
weather.HumidityHighPercent.fillna(value = "NaN", inplace = True)
weather.HumidityHighPercent = weather["HumidityHighPercent"].astype(float)

# %%
weather.loc[weather["DewPointLowF"]=="-","DewPointLowF"] = np.nan
weather.DewPointLowF.fillna(value = "NaN", inplace = True)
weather.DewPointLowF = weather["DewPointLowF"].astype(float)

# %%
weather.loc[weather["DewPointAvgF"]=="-","DewPointAvgF"] = np.nan
weather.DewPointAvgF.fillna(value = "NaN", inplace = True)
weather.DewPointAvgF = weather["DewPointAvgF"].astype(float)

# %%
weather.loc[weather["DewPointHighF"]=="-","DewPointHighF"] = np.nan
weather.DewPointHighF.fillna(value = "NaN", inplace = True)
weather.DewPointHighF = weather["DewPointHighF"].astype(float)

# %%
weather[["TempAvgF", "DewPointAvgF", "HumidityAvgPercent","VisibilityAvgMiles", "WindAvgMPH"]].describe()
# Out:
#           TempAvgF  DewPointAvgF  HumidityAvgPercent  \
# count  1319.000000   1312.000000         1317.000000
# mean     70.642911     56.632622           66.671982
# std      14.045904     14.866272           12.463634
# min      29.000000      8.000000           27.000000
# 25%      62.000000     46.000000           59.000000
# 50%      73.000000     61.000000           67.000000
# 75%      83.000000     69.000000           74.000000
# max      93.000000     76.000000           97.000000
#
#        SeaLevelPressureAvgInches  VisibilityAvgMiles   WindAvgMPH
# count                1316.000000         1307.000000  1317.000000
# mean                   30.022903            9.162204     5.008352
# std                     0.172145            1.458883     2.086450
# min                    29.550000            2.000000     1.000000
# 25%                    29.910000            9.000000     3.000000
# 50%                    30.000000           10.000000     5.000000
# ...

# %%
weather[["TempAvgF", "DewPointAvgF", "HumidityAvgPercent","VisibilityAvgMiles", "WindAvgMPH"]].mode()
# Out:
#    TempAvgF  DewPointAvgF  HumidityAvgPercent  VisibilityAvgMiles  WindAvgMPH
# 0        84          71.0                64.0                10.0         4.0

# %%
import seaborn as sns
sns.boxplot(x = weather["TempAvgF"])

# %%
sns.boxplot(x = weather["DewPointAvgF"])

# %%
sns.boxplot(x = weather["HumidityAvgPercent"])

# %%
sns.boxplot(x = weather["SeaLevelPressureAvgInches"])

# %%
sns.boxplot(x = weather["WindAvgMPH"])

# %%
import thinkstats2
import thinkplot
import matplotlib.pyplot as plt
# %matplotlib inline

weather_2016 = weather[weather.Year == 2016]
weather_2014 = weather[weather.Year == 2014]

w2016 = weather_2016.TempAvgF
w2014 = weather_2014.TempAvgF

# %%
w2016_hist = thinkstats2.Hist(weather_2016.TempAvgF)
w2014_hist = thinkstats2.Hist(weather_2014.TempAvgF)
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Hist(w2014_hist,align = "right", width = width)
thinkplot.Hist(w2016_hist,align = "left", width = width)
thinkplot.Show(xlabel = "Average Temp", ylabel = "Frequency")

# %%
w2016_hist = thinkstats2.Hist(weather_2016.DewPointAvgF)
w2014_hist = thinkstats2.Hist(weather_2014.DewPointAvgF)

width = 0.60
thinkplot.PrePlot(2)
thinkplot.Hist(w2014_hist,align = "right", width = width)
thinkplot.Hist(w2016_hist,align = "left", width = width)
thinkplot.Show(xlabel = " Dew Point Average Temp", ylabel = "Frequency")

# %%
w2016_hist = thinkstats2.Hist(weather_2016.HumidityAvgPercent)
w2014_hist = thinkstats2.Hist(weather_2014.HumidityAvgPercent)

width = 0.60
thinkplot.PrePlot(2)
thinkplot.Hist(w2014_hist,align = "right", width = width)
thinkplot.Hist(w2016_hist,align = "left", width = width)
thinkplot.Show(xlabel = " Humidity Avg Percent", ylabel = "Frequency")
# Out:
# No handles with labels found to put in legend.

# %%
w2016_hist = thinkstats2.Hist(weather_2016.SeaLevelPressureAvgInches)
w2014_hist = thinkstats2.Hist(weather_2014.SeaLevelPressureAvgInches)

width = 0.10
thinkplot.PrePlot(2)
thinkplot.Hist(w2014_hist,align = "right", width = width)
thinkplot.Hist(w2016_hist,align = "left", width = width)
thinkplot.Show(xlabel = " SeaLevel Pressure Avg Inches", ylabel = "Frequency")
# Out:
# No handles with labels found to put in legend.

# %%
w2016_hist = thinkstats2.Hist(weather_2016.VisibilityAvgMiles)
w2014_hist = thinkstats2.Hist(weather_2014.VisibilityAvgMiles)

width = 0.60
thinkplot.PrePlot(2)
thinkplot.Hist(w2014_hist,align = "right", width = width)
thinkplot.Hist(w2016_hist,align = "left", width = width)
thinkplot.Show(xlabel = "Visibility Avg Miles ", ylabel = "Frequency")
# Out:
# No handles with labels found to put in legend.

# %%
w2016_hist = thinkstats2.Hist(weather_2016.WindAvgMPH )
w2014_hist = thinkstats2.Hist(weather_2014.WindAvgMPH )

width = 0.60
thinkplot.PrePlot(2)
thinkplot.Hist(w2014_hist,align = "right", width = width)
thinkplot.Hist(w2016_hist,align = "left", width = width)
thinkplot.Show(xlabel = "Wind Avg MPH  ", ylabel = "Frequency")
# Out:
# No handles with labels found to put in legend.

# %%
#Plotting PMFs

w2016_pmf = thinkstats2.Pmf(weather_2016.TempAvgF)
w2014_pmf = thinkstats2.Pmf(weather_2014.TempAvgF)
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Pmf(w2014_pmf,align = "right", width = width)
thinkplot.Pmf(w2016_pmf,align = "left", width = width)
thinkplot.Show(xlabel = "Average Temp", ylabel = "PMF")

# %%
w2016_pmf = thinkstats2.Pmf(weather_2016.DewPointAvgF)
w2014_pmf = thinkstats2.Pmf(weather_2014.DewPointAvgF)
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Pmf(w2014_pmf,align = "right", width = width)
thinkplot.Pmf(w2016_pmf,align = "left", width = width)
thinkplot.Show(xlabel = "Dew Point Avg F", ylabel = "PMF")

# %%
w2016_pmf = thinkstats2.Pmf(weather_2016.HumidityAvgPercent)
w2014_pmf = thinkstats2.Pmf(weather_2014.HumidityAvgPercent)
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Pmf(w2014_pmf,align = "right", width = width)
thinkplot.Pmf(w2016_pmf,align = "left", width = width)
thinkplot.Show(xlabel = "Humidity Avg Percent", ylabel = "PMF")

# %%
w2016_pmf = thinkstats2.Pmf(weather_2016.SeaLevelPressureAvgInches)
w2014_pmf = thinkstats2.Pmf(weather_2014.SeaLevelPressureAvgInches)
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Pmf(w2014_pmf,align = "right", width = width)
thinkplot.Pmf(w2016_pmf,align = "left", width = width)
thinkplot.Show(xlabel = "Sea Level Pressure Avg Inches", ylabel = "Frequency")
# Out:
# No handles with labels found to put in legend.

# %%
w2016_pmf = thinkstats2.Pmf(weather_2016.VisibilityAvgMiles)
w2014_pmf = thinkstats2.Pmf(weather_2014.VisibilityAvgMiles)
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Pmf(w2014_pmf,align = "right", width = width)
thinkplot.Pmf(w2016_pmf,align = "left", width = width)
thinkplot.Show(xlabel = "Visibility Avg Miles", ylabel = "PMF")

# %%
w2016_pmf = thinkstats2.Pmf(weather_2016.WindAvgMPH )
w2014_pmf = thinkstats2.Pmf(weather_2014.WindAvgMPH )
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Pmf(w2014_pmf,align = "right", width = width)
thinkplot.Pmf(w2016_pmf,align = "left", width = width)
thinkplot.Show(xlabel = "Wind Avg MPH ", ylabel = "PMF")

# %%
# Plotting CDF'S

w2016_cdf = thinkstats2.Cdf(weather_2016.TempAvgF, label = "2016")
w2014_cdf = thinkstats2.Cdf(weather_2014.TempAvgF, label = "2014")
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Cdfs([w2014_cdf, w2016_cdf])
thinkplot.Show(xlabel = "Visibility Avg Miles", ylabel = "Frequency")

# %%
w2016_cdf = thinkstats2.Cdf(weather_2016.DewPointAvgF, label = "2016")
w2014_cdf = thinkstats2.Cdf(weather_2014.DewPointAvgF, label = "2014")
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Cdfs([w2014_cdf, w2016_cdf])
thinkplot.Show(xlabel = "Dew Point Avg F", ylabel = "CDF")

# %%
w2016_cdf = thinkstats2.Cdf(weather_2016.HumidityAvgPercent, label = "2016")
w2014_cdf = thinkstats2.Cdf(weather_2014.HumidityAvgPercent, label = "2014")
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Cdfs([w2014_cdf, w2016_cdf])
thinkplot.Show(xlabel = "Humidity Avg Percent", ylabel = "CDF")

# %%
w2016_cdf = thinkstats2.Cdf(weather_2016.SeaLevelPressureAvgInches, label = "2016")
w2014_cdf = thinkstats2.Cdf(weather_2014.SeaLevelPressureAvgInches, label = "2014")
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Cdfs([w2014_cdf, w2016_cdf])
thinkplot.Show(xlabel = "SeaLevel Pressure Avg Inches", ylabel = "CDF")

# %%
w2016_cdf = thinkstats2.Cdf(weather_2016.VisibilityAvgMiles, label = "2016")
w2014_cdf = thinkstats2.Cdf(weather_2014.VisibilityAvgMiles, label = "2014")
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Cdfs([w2014_cdf, w2016_cdf])
thinkplot.Show(xlabel = "Visibility Avg Miles", ylabel = "CDF")

# %%
w2016_cdf = thinkstats2.Cdf(weather_2016.WindAvgMPH , label = "2016")
w2014_cdf = thinkstats2.Cdf(weather_2014.WindAvgMPH , label = "2014")
width = 0.60
thinkplot.PrePlot(2)
thinkplot.Cdfs([w2014_cdf, w2016_cdf])
thinkplot.Show(xlabel = "Wind Avg MPH ", ylabel = "CDF")

# %%
# Analytical Distributions

SeaLevel_2014 = weather_2014.SeaLevelPressureAvgInches.dropna()

mu, var = thinkstats2.TrimmedMeanVar(SeaLevel_2014, p=0.01)
print('Mean, Var', mu, var)
    
mean, var = thinkstats2.TrimmedMeanVar(SeaLevel_2014, p=0.01)
std = np.sqrt(var)

# plot the model
sigma = np.sqrt(var)
print('Sigma', sigma)
xs, ps = thinkstats2.RenderNormalCdf(mu, sigma, low=29.5, high=30.75)

thinkplot.Plot(xs, ps, label='model', color='0.6')

# plot the data
cdf = thinkstats2.Cdf(SeaLevel_2014, label='data')

thinkplot.PrePlot(1)
thinkplot.Cdf(cdf) 
thinkplot.Config(title='SeaLevel Pressure Avg Inches',
                 xlabel='Avg Sea Level Pressure(inches)',
                 ylabel='CDF')
# Out:
# Mean, Var 30.030362116991643 0.02328092736710609
# Sigma 0.1525808879483472

# %%
SeaLevel_2016 = weather_2016.SeaLevelPressureAvgInches.dropna()

mu, var = thinkstats2.TrimmedMeanVar(SeaLevel_2016, p=0.01)
print('Mean, Var', mu, var)
    
mean, var = thinkstats2.TrimmedMeanVar(SeaLevel_2016, p=0.01)
std = np.sqrt(var)

# plot the model
sigma = np.sqrt(var)
print('Sigma', sigma)
xs, ps = thinkstats2.RenderNormalCdf(mu, sigma, low=29.5, high=30.75)

thinkplot.Plot(xs, ps, label='model', color='0.6')

# plot the data
cdf = thinkstats2.Cdf(SeaLevel_2016, label='data')

thinkplot.PrePlot(1)
thinkplot.Cdf(cdf) 
thinkplot.Config(title='SeaLevel Pressure Avg Inches',
                 xlabel='Avg Sea Level Pressure(inches)',
                 ylabel='CDF')
# Out:
# Mean, Var 30.02697222222222 0.023828888117283932
# Sigma 0.15436608473782035

# %%
mean, var = thinkstats2.TrimmedMeanVar(SeaLevel_2014, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(SeaLevel_2014)
thinkplot.Plot(xs, ys, label='Sea Level Pressure 2014')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='SeaLevel Pressure Avg Inches 2014')

# %%
mean, var = thinkstats2.TrimmedMeanVar(SeaLevel_2016, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(SeaLevel_2016)
thinkplot.Plot(xs, ys, label='Sea Level Pressure 2016')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='SeaLevel Pressure Avg Inches 2016')

# %%
HumidityAvgPercent_2014 = weather_2014.HumidityAvgPercent.dropna()

mu, var = thinkstats2.TrimmedMeanVar(HumidityAvgPercent_2014, p=0.01)
print('Mean, Var', mu, var)
    
mean, var = thinkstats2.TrimmedMeanVar(HumidityAvgPercent_2014, p=0.01)
std = np.sqrt(var)

# plot the model
sigma = np.sqrt(var)
print('Sigma', sigma)
xs, ps = thinkstats2.RenderNormalCdf(mu, sigma, low=30, high=100)

thinkplot.Plot(xs, ps, label='model', color='0.6')

# plot the data
cdf = thinkstats2.Cdf(HumidityAvgPercent_2014, label='data')

thinkplot.PrePlot(2)
thinkplot.Cdf(cdf) 
thinkplot.Config(title='Humidity Avg Percent_2014',
                 xlabel='Avg Humidity Percent',
                 ylabel='CDF')
# Out:
# Mean, Var 64.56424581005587 138.69279985019193
# Sigma 11.77679072796116

# %%
mean, var = thinkstats2.TrimmedMeanVar(HumidityAvgPercent_2014, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(HumidityAvgPercent_2014)
thinkplot.Plot(xs, ys, label='Humidity Avg Percent_2014')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='Humidity Avg Percent_2014')

# %%
HumidityAvgPercent_2016 = weather_2016.HumidityAvgPercent.dropna()

mu, var = thinkstats2.TrimmedMeanVar(HumidityAvgPercent_2016, p=0.01)
print('Mean, Var', mu, var)
    
mean, var = thinkstats2.TrimmedMeanVar(HumidityAvgPercent_2016, p=0.01)
std = np.sqrt(var)

# plot the model
sigma = np.sqrt(var)
print('Sigma', sigma)
xs, ps = thinkstats2.RenderNormalCdf(mu, sigma, low=30, high=100)

thinkplot.Plot(xs, ps, label='model', color='0.6')

# plot the data
cdf = thinkstats2.Cdf(HumidityAvgPercent_2016, label='data')

thinkplot.PrePlot(2)
thinkplot.Cdf(cdf) 
thinkplot.Config(title='Humidity Avg Percent_2016',
                 xlabel='Avg Humidity Percent',
                 ylabel='CDF')
# Out:
# Mean, Var 68.40833333333333 127.24159722222224
# Sigma 11.280141719952912

# %%
mean, var = thinkstats2.TrimmedMeanVar(HumidityAvgPercent_2016, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(HumidityAvgPercent_2016)
thinkplot.Plot(xs, ys, label='Humidity Avg Percent_2016')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='Humidity Avg Percent_2016')

# %%
TempAvgF_2014 = weather_2014.TempAvgF.dropna()

mu, var = thinkstats2.TrimmedMeanVar(TempAvgF_2014, p=0.01)
print('Mean, Var', mu, var)
    
mean, var = thinkstats2.TrimmedMeanVar(TempAvgF_2014, p=0.01)
std = np.sqrt(var)

# plot the model
sigma = np.sqrt(var)
print('Sigma', sigma)
xs, ps = thinkstats2.RenderNormalCdf(mu, sigma, low=30, high=90)

thinkplot.Plot(xs, ps, label='model', color='0.6')

# plot the data
cdf = thinkstats2.Cdf(TempAvgF_2014, label='data')

thinkplot.PrePlot(1)
thinkplot.Cdf(cdf) 
thinkplot.Config(title='Temp Avg (F)',
                 xlabel='Avg Temperature(F)',
                 ylabel='CDF')
# Out:
# Mean, Var 69.45403899721448 205.2116758870586
# Sigma 14.325211198689484

# %%
mean, var = thinkstats2.TrimmedMeanVar(TempAvgF_2014, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(TempAvgF_2014)
thinkplot.Plot(xs, ys, label='TempAvgF_2014')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='TempAvgF_2014')

# %%
TempAvgF_2016 = weather_2016.TempAvgF.dropna()

mu, var = thinkstats2.TrimmedMeanVar(TempAvgF_2016, p=0.01)
print('Mean, Var', mu, var)
    
mean, var = thinkstats2.TrimmedMeanVar(TempAvgF_2016, p=0.01)
std = np.sqrt(var)

# plot the model
sigma = np.sqrt(var)
print('Sigma', sigma)
xs, ps = thinkstats2.RenderNormalCdf(mu, sigma, low=30, high=90)

thinkplot.Plot(xs, ps, label='model', color='0.6')

# plot the data
cdf = thinkstats2.Cdf(TempAvgF_2016, label='data')

thinkplot.PrePlot(1)
thinkplot.Cdf(cdf) 
thinkplot.Config(title='Temp Avg (F)',
                 xlabel='Avg Temperature(F)',
                 ylabel='CDF')
# Out:
# Mean, Var 71.76944444444445 157.077399691358
# Sigma 12.53305228950067

# %%
mean, var = thinkstats2.TrimmedMeanVar(TempAvgF_2016, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(TempAvgF_2016)
thinkplot.Plot(xs, ys, label='TempAvgF_2016')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='TempAvgF_2016')

# %%
# Scatter Plots
weather_df = weather[["TempAvgF", "DewPointAvgF"]]
weather_df.dropna(how = "any", inplace = True)
thinkplot.Scatter(weather_df.TempAvgF, weather_df.DewPointAvgF)
thinkplot.Show(xlabel = "TempAvgF",
               ylabel = "DewPointAvgF",
               axis = [30,90,10, 80])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov


Cov(weather_df.TempAvgF, weather_df.DewPointAvgF)
# Out:
# 186.6338059098007

# %%
def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

Corr(weather_df.TempAvgF, weather_df.DewPointAvgF)
# Out:
# 0.8954689350198304

# %%
Corr(weather_df.TempAvgF, np.log(weather_df.DewPointAvgF))
# Out:
# 0.8637736740748981

# %%
np.corrcoef(weather_df.TempAvgF, weather_df.DewPointAvgF)
# Out:
# array([[1.        , 0.89546894],
#        [0.89546894, 1.        ]])

# %%
def SpearmanCorr(xs, ys):
    xranks = pd.Series(xs).rank()
    yranks = pd.Series(ys).rank()
    return Corr(xranks, yranks)

SpearmanCorr(weather_df.TempAvgF, weather_df.DewPointAvgF)
# Out:
# 0.8902361416696709

# %%
weather_df = weather[["TempAvgF", "HumidityAvgPercent"]]
weather_df.dropna(how = "any", inplace = True)
thinkplot.Scatter(weather_df.TempAvgF, weather_df.HumidityAvgPercent)
thinkplot.Show(xlabel = "TempAvgF",
               ylabel = "HumidityAvgPercent",
               axis = [30,90,30,100])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Cov(weather_df.TempAvgF, weather_df.HumidityAvgPercent)
# Out:
# 5.676032537536991

# %%
Corr(weather_df.TempAvgF, weather_df.HumidityAvgPercent)
# Out:
# 0.03245578682006225

# %%
np.corrcoef(weather_df.TempAvgF, weather_df.HumidityAvgPercent)
# Out:
# array([[1.        , 0.03245579],
#        [0.03245579, 1.        ]])

# %%
SpearmanCorr(weather_df.TempAvgF, weather_df.HumidityAvgPercent)
# Out:
# -0.012359103272491878

# %%
# Statistically Significant

class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data
    
data = weather_2014.TempAvgF.dropna(), weather_2016.TempAvgF.dropna()
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.025

# %%
data = weather_2014.DewPointAvgF.dropna(), weather_2016.DewPointAvgF.dropna()
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %%
data = weather_2014.HumidityAvgPercent.dropna(), weather_2016.HumidityAvgPercent.dropna()
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %%
data = weather_2014.SeaLevelPressureAvgInches.dropna(), weather_2016.SeaLevelPressureAvgInches.dropna()
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.791

# %%
data = weather_2014.VisibilityAvgMiles.dropna(), weather_2016.VisibilityAvgMiles.dropna()
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.783

# %%
from thinkstats2 import Mean, MeanVar, Var, Std, Cov

def LeastSquares(xs, ys):
    meanx, varx = MeanVar(xs)
    meany = Mean(ys)

    slope = Cov(xs, ys, meanx, meany) / varx
    inter = meany - slope * meanx

    return inter, slope

# %%
weather_df = weather[["TempAvgF", "DewPointAvgF"]]
weather_df.dropna(how = "any", inplace = True)
TempAvg = weather_df.TempAvgF
DewPoint = weather_df.DewPointAvgF

inter, slope = LeastSquares(TempAvg,DewPoint)
inter, slope
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (-10.313413587917601, 0.9488198099550387)

# %%
def FitLine(xs, inter, slope):
    fit_xs = np.sort(xs)
    fit_ys = inter + slope * fit_xs
    return fit_xs, fit_ys

fit_xs, fit_ys = FitLine(TempAvg, inter, slope)
thinkplot.Scatter(TempAvg, DewPoint, color='blue', alpha=0.1, s=10)
thinkplot.Plot(fit_xs, fit_ys, color='white', linewidth=3)
thinkplot.Plot(fit_xs, fit_ys, color='red', linewidth=2)
thinkplot.Config(xlabel="Avg Temp(F)",
                 ylabel='Dew Point Avg (F)',
                 axis=[30, 90, 10, 80],
                 legend=False)

# %%
def Residuals(xs, ys, inter, slope):
    xs = np.asarray(xs)
    ys = np.asarray(ys)
    res = ys - (inter + slope * xs)
    return res

def CoefDetermination(ys, res):
    return 1 - Var(res) / Var(ys)

inter, slope = LeastSquares(TempAvg, DewPoint,)
res = Residuals(TempAvg, DewPoint, inter, slope)
r2 = CoefDetermination(TempAvg, res)
r2
# Out:
# 0.7775520105147352

# %%
print('rho', thinkstats2.Corr(TempAvg, DewPoint))
print('R', np.sqrt(r2))
# Out:
# rho 0.8954689350198304
# R 0.8817890963913849
